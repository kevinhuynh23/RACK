# %% [markdown]
# # Airbnb Pricing in Seattle
#
# _Calvin Chan, Alex Huang, Kevin Huynh, Rachel Vuu_
#
# _March 13th, 2019_

# %%
import warnings
warnings.filterwarnings("ignore")

import analysis
import model
# Out:
# C:\Users\huang\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\huang\Anaconda3\lib\site-packages\sklearn\base.py:465: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\huang\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\huang\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# ...

# %% [markdown]
# ## Purpose
#
# For our final project, we selected the [Seattle Airbnb dataset](https://www.kaggle.com/airbnb/seattle), which contains a calendar file documenting the price point and availability of a listing on a day of the year, a descriptive file with a number of features including neighborhood, price, and ratings, and a file consisting of guest reviews.
#
# Airbnb is one of the many technology companies that have completely transformed the sharing economy. Paving the way for other crowd-based marketplaces, Airbnb is one of several prominent startups collectively disrupted the business models of traditional industries (Satopaa & Mehrotra, 2018). Airbnb affords a platform for prospective guests to book accommodations with more flexibility and potentially lower price points, and for hosts to list their properties.
#
# For the scope of this project, the audience we are targeting is potential Airbnb hosts who are considering investing in or renting out a property. For people who need extra income, Airbnb offers a self-regulating (via guest and host reviews), free-market solution for collecting short-term market-rate rents. However, inexperienced and longtime hosts may not be getting the most out of their listing and are missing out on potential revenue every rent day.
#
# In an article by the New York Times, a host says that she grosses nearly $100,000 each year through Airbnb. Despite this income, she still does not feel financially secure due to the costs of upkeep as well as the “slower” months of January, February, and March (Dobbins, 2017). Depending on the location, property size, and other socio-economic factors, hosts may benefit more or less. Additionally, it has been found that Airbnb hosts use marketing logic to target specific demographics  (Lutz & Newlands, 2017). A weak alignment between consumer segmentation and this host targeting can lead to potentially reduced matching efficiency. By performing data analyses on the features of the Seattle Airbnb dataset, we can draw insights on whether properties with a specific set of attributes bring more financial gain than others.
#
# Through our resource, users will gain greater insight into what factors impact the price of a listing. Since there are so many different attributes for a listing, hosts will come with a better understanding of competitive prices. Hosts, interested with garnering high reviews, also will learn what factors influence ratings and reviews. This will allow hosts to stand out among the many listings, attracting more customers and making more money while maximizing the potential of their listing.

# %% [markdown]
# # Data Set

# %%
analysis.lis_raw.head()

# %% [markdown]
# ## Exploratory Data Analysis
#
# The city of Seattle is especially diverse unique in its geography and surrounding landscape. Let's take a look at how Airbnb listings were scattered across the city:

# %%
analysis.fig_map_seattle_listings

# %% [markdown]
# **Observations:**
# - Highest concentration of homestays are within Downtown and Capitol Hill
# - Moderate concentration of homestays in the outer perimeters of central Seattle, with little to no homestays in the SoDo neighborhood below Downtown
# - SoDo is part of the Industrial District, where warehouses and warehouse-style retail stores are more predominate and there are less residential zones
# - Overall, there are more listings in the central and north parts of Seattle than south

# %%
analysis.fig_map_seattle_listings_price

# %% [markdown]
# **Observations:**
# - Downtown and Capitol Hill, the most concentrated areas, tend to be more expensive
# - This is expected since most tourist attractions are within that area
# - Homestays in South Seattle tend to be marked at a lower price point than North and West Seattle
# - These findings suggest there is a tradeoff between commute time to Downtown Seattle and price points for listings

# %%
analysis.fig_num_listings_by_date

# %% [markdown]
# **Observations:**
# - The 3 most notable drops in the number of available listings occur in April, July, and January. A possible explanation for these plunges is Spring break, Summer break, and New Years, when more people vacation because of the holidays.
# - From January to April, the number of listings increases by about 150%. This could be due to the seasons, since temperatures tend to be lower from January to March.
# - After each of the plunges in 2016, there is a consistent, steady increase in the number of available listings of about 100 homestays per month.

# %%
analysis.fig_num_amenities_vs_price

# %% [markdown]
# **Observations:**
# - There does not appear to be any correlation between number of amenities and price of listing.
# - Units with few listed amenities can fall in the same price range as units with an upwards amount of 30 amenities.
# - A data point at a price of $0 suggests there are inconsistencies in the data.

# %%
analysis.fig_num_bedrooms_vs_price

# %% [markdown]
# **Observations:**
# - Although there is some significant overlap, there is a general trend that the price of the homestay increases with the number of beds.
# - There are some outliers in the data, such as the 1 bed homestay listed at \$1000. This could suggest several prospects: other characteristics such as location, amenities, or extravagance of the unit is strongly desirable, or there are inconsistencies in the data.
# - Units with more bedrooms at lower price points could be due to the fact that the bedrooms are not actually available to the guest for use.

# %%
analysis.fig_num_beds_vs_price

# %% [markdown]
# **Observations:**
# - An outlier is the 8 bed unit priced at \$400. This unit could have less desirable characteristics, the user considered couches or air mattresses as a 'bed accomodation', or it could be an inconsistency in the data.
# - There is a general positive correlation between the number of beds, and the price of the AirBnb.
# - After 6 beds, the increase of price of the AirBnb begins to trail off, as a house with more than 6 rooms does not guarentee a signifcant more price of the AirBnb.
# - Generally, there are a lot more houses in the lower price range than the higher price range.

# %%
analysis.fig_num_bathrooms_vs_price

# %% [markdown]
# **Observations:**
# - There is a slight positive correlation between the number of bathrooms, and the price of the AirBnb.
# - After 3 bathrooms, the increase of price of the AirBnb begins to trail off at around $600, as a house with more than 4 rooms does not guarentee a signifcant more price of the AirBnb.
# - A large portion of the Airbnb have less than 4 bathrooms, with the few outliars that have greater than 8 bathrooms - these outliers have among the lowest prices.

# %%
analysis.fig_rating_vs_price

# %% [markdown]
# **Observations:**
# - From the the review rating of 60+, there is a moderate positive correlation between the review ratings and the price point of the Airbnb.
# - Most Airbnbs have 80+ review ratings, and it did not seem like there is a signficant correlation between review ratings and price.
# - Among the most expensive listings, they all have above 90 review ratings - signifying that they are quality listings that are worth the high price.

# %%
analysis.fig_reviews_per_month_vs_price

# %% [markdown]
# **Observations:**
# - In terms of the correlation between reviews per month and review ratings, there was a positive correlation between the two variables.
# - Airbnbs that have review ratings of above 85 had much more reviews per month than the properties that had less ratings - suggesting that there is a significantly more amount of people each people that are giving them business and providing reviews.
# - This is important because it suggests that having high review ratings means there will be more reviews per month, which also means more business per month.
# - Those properties with much lower review ratings had much less reviews per month, suggesting they have less business per month.

# %% [markdown]
# # Modeling

# %%
model.fig_blr
